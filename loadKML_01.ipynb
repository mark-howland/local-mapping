# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon
import pandas as pd
import matplotlib.pyplot as plt

# %%
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'
my_map = gpd.read_file('StAlbans_final_proposals.kml', driver='KML')
my_map
# Out:
#                                Name  \
# 0                       Park Street
# 1                     London Colney
# 2                        St Stephen
# 3                           Sopwell
# 4                        Cunningham
# 5                         St Peters
# 6                          Clarence
# 7                          Hill End
# 8                           Verulam
# 9                      Colney Heath
# 10                        Batchwood
# 11                Marshalswick West
# 12  Marshalswick East & Jersey Farm
# 13                   Bernards Heath
# 14                  Harpenden South
# 15                         Redbourn
# 16                   Harpenden West
# 17                   Harpenden East
# 18          Harpenden North & Rural
# 19       Sandridge & Wheathampstead
#
#                                           Description  \
# 0   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 1   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 2   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 3   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 4   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 5   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 6   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 7   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 8   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 9   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 10  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 11  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 12  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 13  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 14  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 15  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 16  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 17  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 18  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 19  <h4>StAlbans_final_proposals</h4> <ul class="t...
#
#                                              geometry
# 0   GEOMETRYCOLLECTION (POINT (-0.32861 51.71423),...
# 1   GEOMETRYCOLLECTION (POINT (-0.29506 51.72097),...
# 2   GEOMETRYCOLLECTION (POINT (-0.37432 51.71514),...
# 3   GEOMETRYCOLLECTION (POINT (-0.33348 51.73834),...
# 4   GEOMETRYCOLLECTION (POINT (-0.31302 51.73941),...
# 5   GEOMETRYCOLLECTION (POINT (-0.33349 51.75132),...
# 6   GEOMETRYCOLLECTION (POINT (-0.31453 51.75349),...
# 7   GEOMETRYCOLLECTION (POINT (-0.29449 51.75005),...
# 8   GEOMETRYCOLLECTION (POINT (-0.38585 51.74809),...
# 9   GEOMETRYCOLLECTION (POINT (-0.27002 51.74585),...
# 10  GEOMETRYCOLLECTION (POINT (-0.34481 51.76414),...
# 11  GEOMETRYCOLLECTION (POINT (-0.31441 51.76599),...
# 12  GEOMETRYCOLLECTION (POINT (-0.29198 51.76558),...
# 13  GEOMETRYCOLLECTION (POINT (-0.32949 51.76616),...
# 14  GEOMETRYCOLLECTION (POINT (-0.34826 51.80009),...
# 15  GEOMETRYCOLLECTION (POINT (-0.39113 51.78509),...
# 16  GEOMETRYCOLLECTION (POINT (-0.35752 51.81396),...
# 17  GEOMETRYCOLLECTION (POINT (-0.34128 51.82285),...
# 18  GEOMETRYCOLLECTION (POINT (-0.38395 51.81974),...
# 19  GEOMETRYCOLLECTION (POINT (-0.30132 51.80854),...

# %%
type(my_map)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
print(my_map)
# Out:
#                                Name  \
# 0                       Park Street
# 1                     London Colney
# 2                        St Stephen
# 3                           Sopwell
# 4                        Cunningham
# 5                         St Peters
# 6                          Clarence
# 7                          Hill End
# 8                           Verulam
# 9                      Colney Heath
# 10                        Batchwood
# 11                Marshalswick West
# 12  Marshalswick East & Jersey Farm
# 13                   Bernards Heath
# 14                  Harpenden South
# 15                         Redbourn
# 16                   Harpenden West
# 17                   Harpenden East
# 18          Harpenden North & Rural
# 19       Sandridge & Wheathampstead
#
#                                           Description  \
# 0   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 1   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 2   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 3   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 4   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 5   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 6   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 7   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 8   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 9   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 10  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 11  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 12  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 13  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 14  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 15  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 16  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 17  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 18  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 19  <h4>StAlbans_final_proposals</h4> <ul class="t...
#
#                                              geometry
# 0   GEOMETRYCOLLECTION (POINT (-0.32861 51.71423),...
# 1   GEOMETRYCOLLECTION (POINT (-0.29506 51.72097),...
# 2   GEOMETRYCOLLECTION (POINT (-0.37432 51.71514),...
# 3   GEOMETRYCOLLECTION (POINT (-0.33348 51.73834),...
# 4   GEOMETRYCOLLECTION (POINT (-0.31302 51.73941),...
# 5   GEOMETRYCOLLECTION (POINT (-0.33349 51.75132),...
# 6   GEOMETRYCOLLECTION (POINT (-0.31453 51.75349),...
# 7   GEOMETRYCOLLECTION (POINT (-0.29449 51.75005),...
# 8   GEOMETRYCOLLECTION (POINT (-0.38585 51.74809),...
# 9   GEOMETRYCOLLECTION (POINT (-0.27002 51.74585),...
# 10  GEOMETRYCOLLECTION (POINT (-0.34481 51.76414),...
# 11  GEOMETRYCOLLECTION (POINT (-0.31441 51.76599),...
# 12  GEOMETRYCOLLECTION (POINT (-0.29198 51.76558),...
# 13  GEOMETRYCOLLECTION (POINT (-0.32949 51.76616),...
# 14  GEOMETRYCOLLECTION (POINT (-0.34826 51.80009),...
# 15  GEOMETRYCOLLECTION (POINT (-0.39113 51.78509),...
# 16  GEOMETRYCOLLECTION (POINT (-0.35752 51.81396),...
# 17  GEOMETRYCOLLECTION (POINT (-0.34128 51.82285),...
# 18  GEOMETRYCOLLECTION (POINT (-0.38395 51.81974),...
# 19  GEOMETRYCOLLECTION (POINT (-0.30132 51.80854),...

# %%
my_map.plot()
plt.show()

# %%
locations = pd.read_csv('lat_long_dataset.csv')
locations
# Out:
#     longitude  latitude                             Ward ward colortest
# 0    -0.32861  51.71423                      Park Street  PST   #C62828
# 1    -0.29506  51.72097                    London Colney  LCO   #283593
# 2    -0.37432  51.71514                       St Stephen  SST   #FF9800
# 3    -0.33348  51.73834                          Sopwell  SOP   #C62828
# 4    -0.31302  51.73941                       Cunningham  CNN   #283593
# 5    -0.33349  51.75132                        St Peters  STP   #FF9800
# 6    -0.31453  51.75349                         Clarence  CLA   #C62828
# 7    -0.29449  51.75005                         Hill End  HLE   #283593
# 8    -0.38585  51.74809                          Verulam  VER   #FF9800
# 9    -0.27002  51.74585                     Colney Heath  COH   #C62828
# 10   -0.34481  51.76414                        Batchwood  BAT   #283593
# 11   -0.31441  51.76599                Marshalswick West  MWW   #FF9800
# 12   -0.29198  51.76558  Marshalswick East & Jersey Farm  MEJ   #C62828
# 13   -0.32949  51.76616                   Bernards Heath  BNH   #283593
# 14   -0.34826  51.80009                  Harpenden South  HAS   #FF9800
# 15   -0.39113  51.78509                         Redbourn  RDB   #C62828
# 16   -0.35752  51.81396                   Harpenden West  HAW   #283593
# 17   -0.34128  51.82285                   Harpenden East  HAE   #FF9800
# 18   -0.38395  51.81974          Harpenden North & Rural  HNR   #C62828
# 19   -0.30132  51.80854       Sandridge & Wheathampstead  SWH   #283593

# %%
geometric_points = []
for xy in zip(locations['longitude'], locations['latitude']):
   geometric_points.append(Point(xy))

# %%
geo_locations = gpd.GeoDataFrame(locations,
                                 crs = {'init': 'epsg:4326'},
                                 geometry = geometric_points)
# Out:
# /Users/sineadhowland/opt/anaconda3/lib/python3.9/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
print(my_map)
my_map.plot()
geo_locations.plot()
plt.show()
# Out:
#                                Name  \
# 0                       Park Street
# 1                     London Colney
# 2                        St Stephen
# 3                           Sopwell
# 4                        Cunningham
# 5                         St Peters
# 6                          Clarence
# 7                          Hill End
# 8                           Verulam
# 9                      Colney Heath
# 10                        Batchwood
# 11                Marshalswick West
# 12  Marshalswick East & Jersey Farm
# 13                   Bernards Heath
# 14                  Harpenden South
# 15                         Redbourn
# 16                   Harpenden West
# 17                   Harpenden East
# 18          Harpenden North & Rural
# 19       Sandridge & Wheathampstead
#
#                                           Description  \
# 0   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 1   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 2   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 3   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 4   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 5   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 6   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 7   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 8   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 9   <h4>StAlbans_final_proposals</h4> <ul class="t...
# 10  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 11  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 12  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 13  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 14  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 15  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 16  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 17  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 18  <h4>StAlbans_final_proposals</h4> <ul class="t...
# 19  <h4>StAlbans_final_proposals</h4> <ul class="t...
#
#                                              geometry
# 0   GEOMETRYCOLLECTION (POINT (-0.32861 51.71423),...
# 1   GEOMETRYCOLLECTION (POINT (-0.29506 51.72097),...
# 2   GEOMETRYCOLLECTION (POINT (-0.37432 51.71514),...
# 3   GEOMETRYCOLLECTION (POINT (-0.33348 51.73834),...
# 4   GEOMETRYCOLLECTION (POINT (-0.31302 51.73941),...
# 5   GEOMETRYCOLLECTION (POINT (-0.33349 51.75132),...
# 6   GEOMETRYCOLLECTION (POINT (-0.31453 51.75349),...
# 7   GEOMETRYCOLLECTION (POINT (-0.29449 51.75005),...
# 8   GEOMETRYCOLLECTION (POINT (-0.38585 51.74809),...
# 9   GEOMETRYCOLLECTION (POINT (-0.27002 51.74585),...
# 10  GEOMETRYCOLLECTION (POINT (-0.34481 51.76414),...
# 11  GEOMETRYCOLLECTION (POINT (-0.31441 51.76599),...
# 12  GEOMETRYCOLLECTION (POINT (-0.29198 51.76558),...
# 13  GEOMETRYCOLLECTION (POINT (-0.32949 51.76616),...
# 14  GEOMETRYCOLLECTION (POINT (-0.34826 51.80009),...
# 15  GEOMETRYCOLLECTION (POINT (-0.39113 51.78509),...
# 16  GEOMETRYCOLLECTION (POINT (-0.35752 51.81396),...
# 17  GEOMETRYCOLLECTION (POINT (-0.34128 51.82285),...
# 18  GEOMETRYCOLLECTION (POINT (-0.38395 51.81974),...
# 19  GEOMETRYCOLLECTION (POINT (-0.30132 51.80854),...

# %%
plt.style.use("seaborn-poster")
my_map.plot()
plt.title("St Albans District Council Wards")
plt.xlabel("longitude")
plt.ylabel("latitude")
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(locations['longitude'], locations['latitude'], color = "yellow", s = 700, alpha = 0.5)

for i, txt in enumerate(locations['Ward']):
    ax.annotate(txt, (locations['longitude'][i], locations['latitude'][i]))
plt.show()

# %%
my_map3 = pd.merge(my_map, locations, how = 'left', left_index = True, right_index =True)

# %%
my_map['coords'] = my_map['geometry'].apply(lambda x: x.representative_point().coords[:])
my_map['coords'] = [coords[0] for coords in my_map['coords']]
fig, ax = plt.subplots(figsize = (15,15))
my_map.plot(ax=ax, color=my_map3['colortest'], edgecolor='black', linewidth=2,  markersize=0)
for idx, row in my_map3.iterrows():
   plt.annotate(text=row['ward'], xy=row['coords'], horizontalalignment='center', verticalalignment ='center' , fontsize = 14)
plt.title("St Albans District Council Wards", fontsize = 30)
ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
plt.tight_layout()   
plt.show()
